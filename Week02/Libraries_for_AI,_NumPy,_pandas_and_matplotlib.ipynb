# %%
import numpy as np

numbers = np.array([10,20,30,50])

print(numbers)
# Out:
# [10 20 30 50]

# %%
print(numbers.mean())
# Out:
# 27.5

# %%
print(numbers.sum())
# Out:
# 110

# %%
import numpy as np

numbers = np.array([80,70,90,100,60])

print(numbers.mean())
# Out:
# 80.0

# %%
import pandas as pd

student = {
    "Name":["Ali","Siti","Kumar","Mior","Izzat"],
    "Marks":[80,90,75,100,89]
}

df = pd.DataFrame(student) ## untuk menyimpan dan mengurus data dalam bentuk jadual

print(df)
# Out:
#     Name  Marks
# 0    Ali     80
# 1   Siti     90
# 2  Kumar     75
# 3   Mior    100
# 4  Izzat     89

# %% [markdown]
# #df.describe(laporan ringkas)

# %%
print(df.describe())
# Out:
#             Marks
# count    5.000000
# mean    86.800000
# std      9.679876
# min     75.000000
# 25%     80.000000
# 50%     89.000000
# 75%     90.000000
# max    100.000000

# %%
import matplotlib.pyplot as plt

marks = [80,90,75]

plt.plot(marks)

plt.show()

# %%
plt.bar(["Ali","Siti","Kumar"], [80,90,75], color=["purple", "orange", "yellow"])

plt.show()

# %%
import matplotlib.pyplot as plt

df["final_mark"].hist(bins=20)
plt.title("Distribution of final marks (n = 800)")
plt.xlabel("Final mark"); plt.ylabel("Number of students");
plt.show()

df.grouphy("programme")["final_mark"].mean().plot(kind="bar")
plt.title("Average final marks by programme")
plt.ylabel("Average mark"); plt.xticks(rotation=15);
plt.tight_layout(); plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'final_mark'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1291/2885994440.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ...

# %% [markdown]
# #Modular programming

# %%
print("Welcome Haikal")
print("Welcome Amber")
print("Welcome Erma")

# %%
def welcome():
  print("Welcome to AI VISION")

welcome()

# %%
def welcome(name):
  print("welcome", name)

welcome("erma")
welcome("adriana")
welcome("amber")
# Out:
# welcome erma
# welcome adriana
# welcome amber

# %% [markdown]
# anda merupakan seorang AI DATA Analyst di KV Sepang. Anda perlu menganalisis data prestasi pelajar menggunakan python
#
# Gunaka library
#
# Numpy
# Pandas
# Matplotlib
#
# array: 80,75,90,85,70
#
# a. Paparkan:
# semua markah
# markah tertinggi
# markah terendah
# purata markah
# sum
#
# b. bina dataframe
#
# c. gunakan data markah tadi untuk menghasilkan bar chart/graf perlu menunjukkan nama pelajar di paksi X dan markah di Paksi Y

# %%
# ===========================
# Import Library
# ===========================
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ===========================
# Data Markah Pelajar
# ===========================
markah = np.array([80, 75, 90, 85, 70])

# Nama pelajar
nama_pelajar = ["Ali", "Abu", "Siti", "Aisyah", "John"]

# ===========================
# A. Analisis Data
# ===========================
print("=== Analisis Markah Pelajar ===")
print("Semua Markah :", markah)
print("Markah Tertinggi :", np.max(markah))
print("Markah Terendah :", np.min(markah))
print("Purata Markah :", np.mean(markah))
print("Jumlah Markah :", np.sum(markah))

# ===========================
# B. Membina DataFrame
# ===========================
df = pd.DataFrame({
    "Nama Pelajar": nama_pelajar,
    "Markah": markah
})

print("\n=== DataFrame ===")
print(df)

# ===========================
# C. Membina Graf Bar
# ===========================
plt.figure(figsize=(7,5))
plt.bar(df["Nama Pelajar"], df["Markah"])

plt.title("Prestasi Markah Pelajar")
plt.xlabel("Nama Pelajar")
plt.ylabel("Markah")
plt.ylim(0, 100)

# Paparkan nilai markah di atas setiap bar
for i, nilai in enumerate(df["Markah"]):
    plt.text(i, nilai + 1, str(nilai), ha='center')

plt.show()
# Out:
# === Analisis Markah Pelajar ===
# Semua Markah : [80 75 90 85 70]
# Markah Tertinggi : 90
# Markah Terendah : 70
# Purata Markah : 80.0
# Jumlah Markah : 400
#
# === DataFrame ===
#   Nama Pelajar  Markah
# 0          Ali      80
# 1          Abu      75
# 2         Siti      90
# 3       Aisyah      85
# 4         John      70
